# %% [markdown]
# # You do NOT need to move the .ipynb files into this folder!
# This is just an example jupyter notebook file so you can see how I've changed it to a Python file :D

# %%
import matplotlib.pyplot as plt

# %%
# Example 1: Text

# Some code here...
final_result = 12345

print("The final result is: " + str(final_result))
# Out:
# The final result is: 12345

# %%
# Example 2: Graph

# Some code here...
x = [1, 2, 3, 4, 5]
y = [13, 15, 2, 14, 12]

plt.title("Graph Title")
plt.xlabel("X Label")
plt.ylabel("Y Label")
plt.plot(x, y)
plt.show()

# %%
# Example 3: Graph with inputs and multiple plots

### INPUT ###
input1 = 10
input2 = 20
input3 = 30
#############

# Some code here...
x1 = [1, 2, 3, 4, 5, 6, 7]
y1 = [0, input1, 0, input2, 0, input3, 0]

x2 = [1, 2, 3, 4, 5, 6, 7]
y2 = [50, input1, 50, input2, 50, input3, 50]

plt.title("Graph Title")
plt.xlabel("X Label")
plt.ylabel("Y Label")
plt.plot(x1, y1)
plt.plot(x2, y2)
plt.show()
